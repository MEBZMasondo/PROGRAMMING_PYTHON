# %% [markdown]
# # CHAPTER 1

# %% [markdown]
# ## INTRODUCTION TO PYTHON

# %% [markdown]
# ### WHAT IS PYTHON

# %% [markdown]
# ### WHY PYTHON

# %% [markdown]
# ### INSTALLING PYTHON

# %% [markdown]
# ### PYTHON IDE
