# %% [markdown]
# # CHAPTER 2

# %% [markdown]
# ## [CHAPTER NAME]

# %% [markdown]
# - A Simple program to print text
# - It is very simple but valid python

# %%
print('Hello')
# Out:
# Hello

# %%
# Python uses either "" or '' for Strings
print("Hello")
# Out:
# Hello

# %% [markdown]
# Next is a more formal, structured version of the same code

# %%
def main():
    print('Hello')
    
if __name__ == '__main__':
    main()
# Out:
# Hello

# %%
def main():
    message = 'Hello'
    print(message)
    
if __name__ == '__main__':
    main()
# Out:
# Hello
